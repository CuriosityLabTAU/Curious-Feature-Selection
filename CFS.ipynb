# %% [markdown]
# #### 1. Importing all the libraries

# %%
import pandas as pd
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import seaborn as sns
import sys
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn import tree
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# #### 2. Define the Functions

# %%
# Function that create the episode data - sample randomaly
def get_data(episode_size,policy,mode):
    global dataset
    if mode=='train':
        if policy==0:
             dataset=data.sample(n=episode_size)
        else:
            dataset=data
    else:
        dataset = pd.read_csv(location + '/' + file +'_test_int.csv', index_col=0)
    return dataset

# %%
# Function that separate the episode data into features and label
def data_separate (dataset):
    global X
    global y    
    X = dataset.iloc[:,0:dataset.shape[1]-1]  # all rows, all the features and no labels
    y = dataset.iloc[:, -1]  # all rows, label only
    return X,y

# %%
# Function that split the episode data into train and test
def data_split(X,y):
    global X_train_main
    global X_test_main   
    global y_train
    global y_test  
    from sklearn.model_selection import train_test_split
    X_train_main, X_test_main, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=4)
    return X_train_main, X_test_main, y_train, y_test

# %%
# Function that chooses exploration or explotation method
def exploration_explotation(epsilon):
    global exploration 
    if np.random.rand() < epsilon:  
        exploration=1
    else:
        exploration=0    
    return exploration

# %%
# Function that returns all available actions in the state given as an argument: 
def available_actions(number_of_columns,columns,initial_state,current_state,trashold, exploration):
    global exclude
    global all_columns
#    exclude=[]
    all_columns=np.arange(number_of_columns+1)
    # remove columns that have been already selected
    exclude=columns.copy()
    # remove the initial_state and the current_state
    exclude.extend([initial_state, current_state])
    available_act = list(set(all_columns)-set(exclude))
    # remove actions that have negetiv Q value
    if exploration==0:
        index = np.where(Q[current_state,available_act] > trashold)[1]
        available_act= [available_act[i] for i in index.tolist()]
    return available_act

# %%
# Function that chooses which action to be performed according to exploration - explotation method
def sample_next_action(current_state, Q, available_act, exploration):
    global available_act_q_value
    available_act_q_value=np.array(Q[current_state,available_act]).reshape(-1,).tolist()
    if exploration==1: 
        #random selection
        next_action = int(np.random.choice(available_act,1))
    else: 
        #greedy selection according to max value 
        maxQ=max(available_act_q_value)
        count = available_act_q_value.count(maxQ)
        if count > 1:
            max_columns =[i for i in range(len(available_act_q_value)) if available_act_q_value[i] == maxQ]
            i = np.random.choice(max_columns)
        else:
            i = available_act_q_value.index(maxQ)
        next_action=available_act[i]        
    return next_action

# %%
# function that update a list with all selected columns in the episode
def update_columns(action, columns):
    update_columns=columns
    update_columns.append(action)
    return update_columns

# %%
# function that update the X_train and X_test according to the current episode columns list 
def update_X_train_X_test(columns,X_train_main, X_test_main):
    X_train=X_train_main.iloc[:,columns]
    X_test=X_test_main.iloc[:,columns]
    X_train=pd.DataFrame(X_train)
    X_test=pd.DataFrame(X_test)
    return X_train, X_test

# %%
# Function that run the learner and get the error to the current episode columns list
def Learner(X_train, X_test,y_train, y_test):
    global learner
    global y_pred
    if learner_model == 'DT':
        learner = tree.DecisionTreeClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)
    elif learner_model == 'KNN':
        learner = KNeighborsClassifier(metric='hamming',n_neighbors=5)
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)        
    elif learner_model == 'SVM':
        learner = SVC()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)        
    elif learner_model == 'NB':
        learner = MultinomialNB()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)
    elif learner_model == 'AB':
        learner = AdaBoostClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    elif learner_model == 'GB':
        learner = GradientBoostingClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    accuracy=metrics.accuracy_score(y_test, y_pred)
    error=1-accuracy
    return error

# %%
# Function that updates the Q matrix according to the path selected and the Q 
def q_update(current_state ,action,learning_rate, reward):
    # next_state = current action
    max_index = np.where(Q[action,] == np.max(Q[action,]))[1]    
    if max_index.shape[0] > 1:
        #np.random.seed(seed)
        max_index = int(np.random.choice(max_index, size = 1))
    else:
        max_index = int(max_index)
    max_value = Q[action, max_index]
    #we start with 1 for all Q values and update with reward only at the 1st time
    if Q[current_state, action]==1:
        Q[current_state, action] = learning_rate*reward
    else:
         Q[current_state, action] = Q[current_state, action]+ learning_rate*(reward + (discount_factor * max_value)-Q[current_state, action])
    #Q[current_state, action] = Q[current_state, action]+ learning_rate*(reward + (discount_factor * max_value)-Q[current_state, action])

# %% [markdown]
# ### Experiment mangment

# %% [markdown]
# #### 3. Define the parameters

# %%
#Experiment: 
experiment='new_No_show_DT_2'
number_of_experiment=5
# Dataset parameters #
location = 'C:/Users/mmoran1/Documents/TAU/Thesis/Datasets'
outputlocation='C:/Users/mmoran1/Documents/TAU/Thesis'
file='No_show' #adult #diabetic_data #Census_Income_KDD
#np.random.seed(3)

# Q learning parameter # 
learning_rate=0.005
discount_factor=0.01
epsilon = 0.1

# Learner and episode parameters #
learner_model = 'DT' #DT #KNN #SVM
episode_size=100
internal_trashold=0
external_trashold=0
filename= file +'_int.csv'

#Experiments folder management: 
if not os.path.exists('/Experiments'):
    os.makedirs('/Experiments') 
if not os.path.exists('Experiments/'+ str(experiment)):
    os.makedirs('Experiments/'+ str(experiment))
else:
    shutil.rmtree('Experiments/'+ str(experiment))          #removes all the subdirectories!
    os.makedirs('Experiments/'+ str(experiment))
writer = pd.ExcelWriter('Experiments/'+ str(experiment) + '/df.xlsx') 



text_file = open('Experiments/'+ str(experiment) +'/parameters.txt', "w")
text_file.write('experiment: ' + str(experiment)+ '\n')
text_file.write('number of experiments: ' + str(number_of_experiment)+ '\n')
text_file.write('file: ' + str(file)+ '\n')
text_file.write('learner model: ' + str(learner_model)+ '\n')
text_file.write('episode size: ' + str(episode_size)+ '\n')
#text_file.write('numbers of epocs: ' + str(epocs)+ '\n')
text_file.write('internal trashold: ' + str(internal_trashold)+ '\n')
text_file.write('external trashold: ' + str(external_trashold)+ '\n')
 
text_file.close()

# %% [markdown]
# #### 4. Run all experiments

# %%
for e in range (number_of_experiment):
    if not os.path.exists('Experiments/'+ str(experiment)+ '/'+ str(e)):
        os.makedirs('Experiments/'+ str(experiment)+ '/'+ str(e))
    else:
        shutil.rmtree('Experiments/'+ str(experiment)+ '/'+ str(e))          #removes all the subdirectories!
        os.makedirs('Experiments/'+ str(experiment)+ '/'+ str(e))
    print ('Experiments ' + str(e) + ' start')
##########################Experiment setup##########################
    # Read the data
    data = pd.read_csv(location + '/' + filename, index_col=0)
    #Set the number of iterations:
    interations=10*len(data.index)/episode_size
#    interations=2400
    # Set the number of columns exclude the class column
    number_of_columns=data.shape[1]-1 
    print ("number of columns: "+ str(number_of_columns) +" (exclude class column)" ) 
    # Set the number of episodes 
    # episodes_number=epocs*len(data.index)/episode_size
    episodes_number=interations
    print ("Number of episodes: "+ str(episodes_number) ) 
    # Initialize matrix Q as a 1 values matrix:
    #Q = np.matrix(np.ones([number_of_columns+1,number_of_columns+1])) # we will use the last dummy columns as initial state s
    Q = np.matrix(np.ones([number_of_columns+1,number_of_columns+1])) # we will use the last dummy columns as initial state s
    # Set initial_state to be the last dummy column we have created
    initial_state=number_of_columns
    # define data frame to save episode policies results
    df = pd.DataFrame(columns=('episode','episode_columns','policy_columns','policy_accuracy_train','policy_accuracy_test'))
    print ("initial state number: "+ str(initial_state) + " (the last dummy column we have created)") 
    ##########################  episode  ##########################  
    for i in range (int(episodes_number)):
    ########## Begining of episode  ############
        # Initiate lists for available_act, episode_columns and and the policy mode & episode_error
        episode_available_act=list(np.arange(number_of_columns))
        episode_columns=[]
        policy=0
        episode_error=0
        # Initiate the error to 0.5
        episode_last_error=0.5
        # Initiate current_state to be initial_state
        episode_current_state=initial_state
        # Create the episode data 
        episode= get_data(episode_size, policy=0, mode='train')
        # Separate the episode data into features and label
        X_episode,y_episode=data_separate(episode)
        # Split the data into train and test 
        X_train_main_episode, X_test_main_episode, y_train_episode, y_test_episode = data_split(X_episode,y_episode)
        if i<episodes_number*0.25:
            epsilon=0.9
            learning_rate=0.09
        elif i<episodes_number*0.5:
            epsilon=0.5
            learning_rate=0.05
        elif i<episodes_number*0.75:
            epsilon=0.3
            learning_rate=0.01
        else:
            epsilon=0.1
            learning_rate=0.005
        ########## Q learning start ############

        while len(episode_available_act)>0:
            # Get exploration or explotation flag 
            exploration=exploration_explotation(epsilon)
            # Get available actions in the current state
            episode_available_act = available_actions(number_of_columns,episode_columns,initial_state,episode_current_state,internal_trashold,exploration)
            if len(episode_available_act)>0:
                # Sample next action to be performed
                episode_action = sample_next_action(episode_current_state, Q, episode_available_act, exploration)
                # Update the episode_columns
                episode_columns=update_columns(episode_action,episode_columns)
                # Update the dataset to include all episode columns + current selected action (column)
                X_train_episode, X_test_episode =update_X_train_X_test(episode_columns,X_train_main_episode, X_test_main_episode)
                # Update the accuracy of the current columns
                episode_error= Learner(X_train_episode, X_test_episode, y_train_episode, y_test_episode)
                # Update reward
                episode_reward=episode_last_error-episode_error
                # Update Q matrix
                q_update(episode_current_state,episode_action,learning_rate, episode_reward)
                # Update parameters for next round 
#                 if episode_current_state==initial_state:
#                     beta=abs(episode_reward-Q[episode_current_state,episode_action])
#                     epsilon=final_epsilon+(beta*(1-final_epsilon))
                #    learning_rate=final_learning_rate+(beta*(1-final_learning_rate))
                episode_current_state=episode_action
                episode_last_error=episode_error
                 
        ########## Q learning End ############

        #Save Q matrix: 
        if (i%100 ==0):
            Q_save=pd.DataFrame(Q)
            Q_save.to_csv('Experiments/'+ str(experiment)+ '/'+ str(e)+ '/Q.'+ str(i+1) + '.csv') 

        # Calculate policy 
        policy_available_actions=list(np.arange(number_of_columns))
        policy_columns=[]
        policy_current_state=initial_state
        while len(policy_available_actions)>0:
            # Get available actions in the current state
            policy_available_actions = available_actions(number_of_columns,policy_columns,initial_state,policy_current_state, external_trashold, exploration=0)
            # # Sample next action to be performed
            if len(policy_available_actions)>0:
                policy_select_action = sample_next_action(policy_current_state, Q, policy_available_actions, exploration=0)
                # Update the episode_columns
                policy_columns=update_columns(policy_select_action,policy_columns)
                policy_current_state=policy_select_action
        # Calculate policy_accuracy    
        if len(policy_columns)>0:
            ##for training dataset##
            policy_data=get_data(episode_size,policy=1,mode='train')
            X_policy,y_policy=data_separate(policy_data)
            X_train_main_policy, X_test_main_policy, y_train_policy, y_test_policy = data_split(X,y)
            X_train_policy, X_test_policy =update_X_train_X_test(policy_columns, X_train_main_policy, X_test_main_policy)
            policy_error=Learner(X_train_policy, X_test_policy,y_train_policy, y_test_policy)
            policy_accuracy_train=1-policy_error
            ##for testing dataset##
            policy_data=get_data(episode_size,policy=1,mode='test')
            X_policy,y_policy=data_separate(policy_data)
            X_train_main_policy, X_test_main_policy, y_train_policy, y_test_policy = data_split(X,y)
            X_train_policy, X_test_policy =update_X_train_X_test(policy_columns, X_train_main_policy, X_test_main_policy)
            policy_error=Learner(X_train_policy, X_test_policy,y_train_policy, y_test_policy)
            policy_accuracy_test=1-policy_error 
        else:
            policy_accuracy_train=0 
            policy_accuracy_test=0
        df=df.append({'episode':str(i+1), 'episode_columns':str(episode_columns),'policy_columns':str(policy_columns),'policy_accuracy_train':policy_accuracy_train,'policy_accuracy_test':policy_accuracy_test}, ignore_index=True)
        #Prints
        print ("episode "+ str(i+1) +" start") 
        print ("episode columns: "+ str(episode_columns) + " epsilon: " + str(epsilon) + " learning rate: " + str(learning_rate) + " error: " +str(episode_error))
        print ("episode policy:" + str(policy_columns) + " train accuracy: " + str(policy_accuracy_train)  + " test accuracy: " +str(policy_accuracy_test)) 
        print ("episode "+ str(i+1) +" end") 
    ########## End of episode  ############
    df.to_excel(writer, 'Experiment' + str(e))
    df_plot=df[['episode','policy_accuracy_train','policy_accuracy_test']]
    plot=df_plot.plot()
    fig = plot.get_figure()
    fig.savefig('Experiments/'+ str(experiment) + '/plot_experiment_' + str(e) +'.png')
writer.save()
# Out:
# Experiments 0 start
# number of columns: 12 (exclude class column)
# Number of episodes: 27000.0
# initial state number: 12 (the last dummy column we have created)
# episode 1 start
# episode columns: [2, 5, 3, 4, 11, 6, 9, 8, 0, 7, 10, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[11, 10, 0, 4, 3, 5, 7, 6, 1, 8, 2, 9] train accuracy: 0.62012962963 test accuracy: 0.584166666667
# episode 1 end
# episode 2 start
# episode columns: [4, 8, 6, 7, 2, 0, 9, 3, 5, 10, 11, 1] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[0, 3, 1, 6, 8, 10, 5, 2, 9, 7, 4] train accuracy: 0.677314814815 test accuracy: 0.6165
# episode 2 end
# episode 3 start
# episode columns: [9, 6, 0, 5, 4, 7, 3, 8, 10, 1, 2, 11] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[5, 6, 2, 4, 1, 11, 0, 3, 10, 9, 7, 8] train accuracy: 0.619740740741 test accuracy: 0.587333333333
# episode 3 end
# episode 4 start
# episode columns: [7, 4, 8, 10, 6, 2, 5, 3, 0, 1, 11, 9] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[0, 10, 8, 3, 6, 1, 9, 2, 7, 5, 11, 4] train accuracy: 0.619537037037 test accuracy: 0.5845
# episode 4 end
# episode 5 start
# episode columns: [10, 4, 11, 9, 0, 8, 1, 5, 6, 2, 3, 7] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[1, 4, 9, 10, 3, 2, 8, 5, 0, 6, 11, 7] train accuracy: 0.619722222222 test accuracy: 0.585166666667
# episode 5 end
# episode 6 start
# episode columns: [9, 6, 1, 7, 8, 5, 11, 3, 2, 0, 10, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[3, 10, 7, 0, 4, 5, 1, 9, 11, 8, 2, 6] train accuracy: 0.6195 test accuracy: 0.584333333333
# episode 6 end
# episode 7 start
# episode columns: [4, 5, 0, 10, 11, 2, 1, 9, 8, 3, 6, 7] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[6, 4, 1, 3, 10, 8, 7, 0, 11, 5, 9, 2] train accuracy: 0.619722222222 test accuracy: 0.585666666667
# episode 7 end
# episode 8 start
# episode columns: [11, 8, 3, 5, 10, 6, 4, 2, 7, 9, 0, 1] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[3, 10, 2, 4, 9, 7, 0, 11, 5, 1, 8] train accuracy: 0.620388888889 test accuracy: 0.581166666667
# episode 8 end
# episode 9 start
# episode columns: [5, 11, 9, 3, 1, 7, 8, 2, 6, 4, 0, 10] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[0, 11, 10, 3, 9, 1, 6, 8, 7, 5, 2, 4] train accuracy: 0.619759259259 test accuracy: 0.584166666667
# episode 9 end
# episode 10 start
# episode columns: [8, 11, 3, 1, 4, 2, 7, 6, 5, 0] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[3, 9, 10, 7, 1, 6, 8, 4, 0, 2, 11, 5] train accuracy: 0.619944444444 test accuracy: 0.586666666667
# episode 10 end
# episode 11 start
# episode columns: [3, 2, 10, 0, 8, 4, 6, 9, 5, 11, 1, 7] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[1, 3, 9, 7, 11, 0, 2, 8, 10, 5] train accuracy: 0.621388888889 test accuracy: 0.5785
# episode 11 end
# episode 12 start
# episode columns: [11, 10, 3, 9, 0, 6, 7, 2, 1, 8, 4, 5] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 3, 10, 9, 7, 11, 4, 1, 0, 2, 8] train accuracy: 0.626962962963 test accuracy: 0.5875
# episode 12 end
# episode 13 start
# episode columns: [7, 4, 9, 1, 2, 8, 0, 3, 11, 5, 6, 10] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[0, 4, 10, 8, 9, 7, 5, 1, 3, 11] train accuracy: 0.649351851852 test accuracy: 0.5965
# episode 13 end
# episode 14 start
# episode columns: [5, 3, 8, 7, 2, 11, 0, 1, 9, 4, 6] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[0, 2, 9, 10, 5, 8, 3, 11, 7, 1, 6, 4] train accuracy: 0.62012962963 test accuracy: 0.584166666667
# episode 14 end
# episode 15 start
# episode columns: [1, 6, 10, 5, 4, 3, 7, 9, 0, 8, 2, 11] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[6, 8, 9, 7, 1, 3, 10, 2, 4, 0, 11] train accuracy: 0.626851851852 test accuracy: 0.5865
# episode 15 end
# episode 16 start
# episode columns: [10, 9, 5, 6, 8, 1, 4, 7, 11, 3, 2, 0] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[0, 11, 7, 5, 2, 4, 1, 10, 8, 9, 3] train accuracy: 0.620407407407 test accuracy: 0.582166666667
# episode 16 end
# episode 17 start
# episode columns: [9, 6, 3, 0, 8, 10, 1, 11, 2, 5, 4, 7] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[6, 11, 7, 0, 2, 4, 1, 10, 8, 9, 5] train accuracy: 0.621666666667 test accuracy: 0.583166666667
# episode 17 end
# episode 18 start
# episode columns: [3, 6, 1, 11, 2, 4, 5, 7, 0, 10, 8, 9] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[0, 11, 7, 1, 3, 10, 2, 9, 8, 4, 5] train accuracy: 0.62037037037 test accuracy: 0.5775
# episode 18 end
# episode 19 start
# episode columns: [7, 0, 9, 5, 4, 8, 2, 11, 1, 10, 3, 6] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 11, 7, 5, 9, 10, 2, 3] train accuracy: 0.691814814815 test accuracy: 0.671333333333
# episode 19 end
# episode 20 start
# episode columns: [0, 7, 2, 8, 9, 11, 4, 5, 1, 10, 6, 3] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[6, 11, 7, 5, 9, 10, 2, 3] train accuracy: 0.691740740741 test accuracy: 0.671166666667
# episode 20 end
# episode 21 start
# episode columns: [9, 7, 2, 4, 5, 6, 10, 11, 8, 1, 3, 0] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[6, 11, 7, 5, 8, 0, 4, 10, 2, 9, 3] train accuracy: 0.633962962963 test accuracy: 0.592666666667
# episode 21 end
# episode 22 start
# episode columns: [2, 1, 6, 11, 7, 3, 0, 10, 8, 5, 4, 9] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[6, 5, 8, 0, 4, 1, 7, 2, 9, 10, 3, 11] train accuracy: 0.619685185185 test accuracy: 0.583333333333
# episode 22 end
# episode 23 start
# episode columns: [2, 9, 10, 11, 4, 1, 5, 7, 6, 0, 3, 8] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[6, 5, 9, 2, 10, 7, 1, 0, 4] train accuracy: 0.685277777778 test accuracy: 0.633833333333
# episode 23 end
# episode 24 start
# episode columns: [10, 9, 3, 11, 6, 5, 4, 2, 7, 0, 8, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[6, 1, 0, 11, 8, 2, 10, 7, 5, 9, 3] train accuracy: 0.619648148148 test accuracy: 0.582666666667
# episode 24 end
# episode 25 start
# episode columns: [2, 7, 11, 4, 1, 0, 9, 5, 3, 10, 8, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[6, 4, 10, 2, 3, 11, 8, 0, 9, 5, 7, 1] train accuracy: 0.619666666667 test accuracy: 0.584833333333
# episode 25 end
# episode 26 start
# episode columns: [6, 9, 1, 7, 5, 10, 0, 8, 3, 11, 4] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[7, 1, 0, 11, 8, 2, 10, 5, 9, 3] train accuracy: 0.621185185185 test accuracy: 0.580166666667
# episode 26 end
# episode 27 start
# episode columns: [1, 0, 8, 6, 2, 11, 7, 10, 5, 3, 9, 4] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[7, 1, 0, 4, 10, 2, 3, 11, 8, 9, 5] train accuracy: 0.620592592593 test accuracy: 0.5825
# episode 27 end
# episode 28 start
# episode columns: [6, 2, 1, 0, 3, 10, 7, 4, 5, 9, 11, 8] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[7, 1, 0, 4, 10, 2, 3, 11, 8, 9, 5] train accuracy: 0.620333333333 test accuracy: 0.582333333333
# episode 28 end
# episode 29 start
# episode columns: [11, 10, 2, 8, 3, 7, 6, 0, 5, 1, 9, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[7, 1, 0, 2, 10, 5, 8, 9, 11, 4, 6] train accuracy: 0.621333333333 test accuracy: 0.5845
# episode 29 end
# episode 30 start
# episode columns: [6, 3, 10, 0, 9, 7, 4, 5, 11, 8, 1, 2] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[7, 1, 0, 11, 10, 5, 2, 6, 9, 8, 3] train accuracy: 0.620703703704 test accuracy: 0.583333333333
# episode 30 end
# episode 31 start
# episode columns: [8, 1, 2, 3, 6, 10, 5, 4, 0, 11, 7] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[7, 1, 0, 2, 10, 3, 11, 8, 9, 5] train accuracy: 0.621518518519 test accuracy: 0.581
# episode 31 end
# episode 32 start
# episode columns: [5, 0, 7, 6, 10, 3, 2, 9, 11, 1, 8, 4] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[7, 1, 0, 2, 10, 3, 11, 8, 9, 5] train accuracy: 0.621018518519 test accuracy: 0.579833333333
# episode 32 end
# episode 33 start
# episode columns: [6, 10, 4, 7, 11, 2, 8, 9, 1, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[7, 1, 0, 2, 10, 3, 11, 8, 9, 5] train accuracy: 0.621333333333 test accuracy: 0.581833333333
# episode 33 end
# episode 34 start
# episode columns: [7, 11, 2, 5, 0, 6, 1, 4, 3, 8, 10, 9] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 5, 8, 0, 4, 10, 3, 7, 1, 9, 11, 6] train accuracy: 0.619537037037 test accuracy: 0.584833333333
# episode 34 end
# episode 35 start
# episode columns: [6, 4, 0, 10, 5, 2, 8, 9, 3, 11, 1, 7] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.619666666667 test accuracy: 0.584333333333
# episode 35 end
# episode 36 start
# episode columns: [4, 11, 10, 7, 3, 1, 6, 0, 8, 5, 2, 9] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.619333333333 test accuracy: 0.583
# episode 36 end
# episode 37 start
# episode columns: [6, 9, 7, 3, 0, 4, 10, 1, 5, 2, 8, 11] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 10, 1, 0, 2, 5, 8, 9, 11, 4, 7] train accuracy: 0.621814814815 test accuracy: 0.5835
# episode 37 end
# episode 38 start
# episode columns: [6, 10, 1, 11, 8, 2, 9, 4, 5, 7, 3, 0] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.620296296296 test accuracy: 0.5855
# episode 38 end
# episode 39 start
# episode columns: [11, 4, 8, 1, 7, 10, 6, 2, 9, 0, 5, 3] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.619462962963 test accuracy: 0.588666666667
# episode 39 end
# episode 40 start
# episode columns: [9, 2, 5, 4, 11, 1, 6, 0, 7, 3, 10, 8] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.619740740741 test accuracy: 0.585333333333
# episode 40 end
# episode 41 start
# episode columns: [2, 7, 6, 11, 1, 8, 10, 0, 3, 9, 5, 4] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.619351851852 test accuracy: 0.584833333333
# episode 41 end
# episode 42 start
# episode columns: [7, 6, 3, 8, 9, 0, 5, 2, 4, 11, 10, 1] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[6, 10, 3, 7, 1, 0, 2, 5, 8, 9, 11, 4] train accuracy: 0.620055555556 test accuracy: 0.583833333333
# episode 42 end
# episode 43 start
# episode columns: [2, 5, 8, 4, 3, 9, 11, 0, 1, 7, 10, 6] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 10, 3, 7, 1, 0, 9, 11, 8, 5] train accuracy: 0.622037037037 test accuracy: 0.581166666667
# episode 43 end
# episode 44 start
# episode columns: [9, 1, 10, 5, 2, 11, 4, 7, 6, 8, 0, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 10, 3, 7, 1, 0, 9, 11, 8, 5] train accuracy: 0.622074074074 test accuracy: 0.581
# episode 44 end
# episode 45 start
# episode columns: [2, 10, 9, 11, 4, 5, 0, 8, 3, 7, 1, 6] epsilon: 0.9 learning rate: 0.09 error: 0.1
# episode policy:[2, 5, 10, 3, 7, 4, 0, 8, 9, 11, 6, 1] train accuracy: 0.619314814815 test accuracy: 0.581333333333
# episode 45 end
# episode 46 start
# episode columns: [4, 10, 8, 7, 1, 0, 6, 9, 3, 11, 5, 2] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 5, 10, 3, 7, 4, 0, 8, 9, 11, 6, 1] train accuracy: 0.619259259259 test accuracy: 0.585166666667
# episode 46 end
# episode 47 start
# episode columns: [2, 5, 7, 4, 8, 11, 9, 10, 6, 0, 1, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 10, 3, 7, 4, 8, 0, 9, 11, 6, 1, 5] train accuracy: 0.619759259259 test accuracy: 0.582
# episode 47 end
# episode 48 start
# episode columns: [3, 9, 5, 0, 7, 4, 11, 6, 1, 10, 2, 8] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 10, 3, 7, 4, 8, 0, 9, 11, 6, 1, 5] train accuracy: 0.620092592593 test accuracy: 0.586833333333
# episode 48 end
# episode 49 start
# episode columns: [6, 9, 0, 2, 1, 3, 8, 5, 11, 10, 7, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 10, 7, 1, 0, 8, 9, 11, 4, 3] train accuracy: 0.627648148148 test accuracy: 0.5845
# episode 49 end
# episode 50 start
# episode columns: [8, 5, 2, 11, 4, 9, 10, 0, 1, 7, 6, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 10, 7, 6, 1, 0, 8, 9, 11, 4, 3] train accuracy: 0.626796296296 test accuracy: 0.587333333333
# episode 50 end
# episode 51 start
# episode columns: [4, 9, 0, 11, 2, 6, 7, 8, 3, 10, 1, 5] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 6, 10, 7, 8, 0, 1, 5] train accuracy: 0.682925925926 test accuracy: 0.6215
# episode 51 end
# episode 52 start
# episode columns: [10, 1, 7, 3, 2, 4, 6, 9, 8, 5, 0, 11] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 10, 7, 8, 0, 1, 5] train accuracy: 0.682925925926 test accuracy: 0.621
# episode 52 end
# episode 53 start
# episode columns: [5, 7, 10, 4, 2, 1, 8, 6, 3] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 6, 10, 7, 8, 0, 1, 5] train accuracy: 0.682888888889 test accuracy: 0.620333333333
# episode 53 end
# episode 54 start
# episode columns: [11, 6, 3, 10, 9, 7, 4, 0, 2, 1, 8, 5] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 10, 7, 8, 0, 1, 5] train accuracy: 0.683074074074 test accuracy: 0.6215
# episode 54 end
# episode 55 start
# episode columns: [9, 2, 1, 0, 8, 5, 10, 6, 11, 4, 3, 7] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[2, 6, 11, 10, 7, 8, 0, 1, 5] train accuracy: 0.621796296296 test accuracy: 0.587666666667
# episode 55 end
# episode 56 start
# episode columns: [11, 10, 8, 0, 1, 7, 2, 9, 5, 4, 3, 6] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 6, 11, 10, 7, 8, 0, 1, 5, 4, 9] train accuracy: 0.621666666667 test accuracy: 0.584166666667
# episode 56 end
# episode 57 start
# episode columns: [4, 2, 8, 5, 0, 7, 9, 3, 6, 11, 10, 1] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[4, 0, 2, 6, 10, 7, 8, 9, 11, 3, 1, 5] train accuracy: 0.619777777778 test accuracy: 0.583
# episode 57 end
# episode 58 start
# episode columns: [8, 0, 3, 6, 4, 1, 2, 5, 9, 10, 7, 11] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[4, 0, 2, 5, 7, 6, 10, 3, 1, 11, 8, 9] train accuracy: 0.619351851852 test accuracy: 0.584
# episode 58 end
# episode 59 start
# episode columns: [4, 8, 9, 11, 2, 6, 5, 3, 0, 1, 7, 10] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[2, 5, 4, 0, 7, 6, 10, 3, 1, 11, 8, 9] train accuracy: 0.619944444444 test accuracy: 0.584166666667
# episode 59 end
# episode 60 start
# episode columns: [5, 3, 7, 1, 11, 9, 8, 2, 6, 10, 0, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 5, 4, 0, 7, 6, 10, 3, 1, 9, 8] train accuracy: 0.677185185185 test accuracy: 0.617166666667
# episode 60 end
# episode 61 start
# episode columns: [1, 6, 8, 2, 4, 7, 9, 5, 0, 3, 10] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 5, 4, 0, 7, 6, 10, 3, 1, 9, 8] train accuracy: 0.677296296296 test accuracy: 0.617
# episode 61 end
# episode 62 start
# episode columns: [1, 4, 3, 6, 2, 10, 7, 5] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 10, 7, 6, 1, 5, 4, 0, 9, 8, 3] train accuracy: 0.677277777778 test accuracy: 0.616666666667
# episode 62 end
# episode 63 start
# episode columns: [2, 1, 10, 9, 5, 8, 4, 11, 3, 0, 7, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 10, 7, 6, 1, 5, 4, 0, 9, 8, 3] train accuracy: 0.677314814815 test accuracy: 0.616833333333
# episode 63 end
# episode 64 start
# episode columns: [2, 10, 6, 11, 4, 8, 0, 7, 9, 3, 1, 5] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 10, 7, 6, 1, 5, 4, 0, 9, 8, 3] train accuracy: 0.67737037037 test accuracy: 0.616833333333
# episode 64 end
# episode 65 start
# episode columns: [2, 11, 4, 9, 8, 7, 5, 10, 3, 6, 0, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 10, 7, 6, 1, 5, 4, 0, 9, 11, 8, 3] train accuracy: 0.619796296296 test accuracy: 0.5895
# episode 65 end
# episode 66 start
# episode columns: [5, 4, 11, 3, 6, 0, 7, 8, 10, 2, 9, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 10, 7, 8, 0, 9, 1, 5, 4] train accuracy: 0.683685185185 test accuracy: 0.620333333333
# episode 66 end
# episode 67 start
# episode columns: [6, 10, 11, 5, 9, 2, 0, 7, 1, 8, 4, 3] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 10, 7, 8, 0, 9, 1, 5, 4] train accuracy: 0.683444444444 test accuracy: 0.621166666667
# episode 67 end
# episode 68 start
# episode columns: [10, 11, 8, 5, 2, 9, 0, 6, 4, 3, 7, 1] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 10, 7, 8, 0, 9, 1, 5, 4] train accuracy: 0.683666666667 test accuracy: 0.6215
# episode 68 end
# episode 69 start
# episode columns: [7, 5, 9, 3, 1, 6, 11, 4, 2, 10, 0, 8] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 10, 7, 8, 0, 9, 1, 5, 4] train accuracy: 0.683611111111 test accuracy: 0.620833333333
# episode 69 end
# episode 70 start
# episode columns: [3, 11, 0, 1, 5, 2, 8, 9, 7, 10, 6, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 10, 7, 8, 0, 1, 5, 4, 9, 11, 3, 6] train accuracy: 0.619722222222 test accuracy: 0.585166666667
# episode 70 end
# episode 71 start
# episode columns: [8, 2, 10, 6, 3, 5, 4, 9, 1, 0, 7, 11] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 10, 7, 8, 0, 1, 5, 4, 9, 11, 3, 6] train accuracy: 0.6195 test accuracy: 0.585666666667
# episode 71 end
# episode 72 start
# episode columns: [9, 2, 10, 1, 7, 6, 5, 11, 3, 4, 0, 8] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 10, 7, 8, 0, 1, 5, 4, 9, 11, 3, 6] train accuracy: 0.619740740741 test accuracy: 0.585833333333
# episode 72 end
# episode 73 start
# episode columns: [11, 10, 1, 2, 5, 4, 6, 8, 3, 9, 7, 0] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 10, 7, 8, 0, 1, 5, 4, 9, 11, 3, 6] train accuracy: 0.620203703704 test accuracy: 0.586166666667
# episode 73 end
# episode 74 start
# episode columns: [0, 3, 1, 8, 11, 7, 2, 6, 4, 9, 10] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 10, 7, 8, 0, 1, 5, 4, 6, 9, 11, 3] train accuracy: 0.619092592593 test accuracy: 0.585333333333
# episode 74 end
# episode 75 start
# episode columns: [2, 10, 1, 8, 6, 0, 4, 3, 7, 9, 5, 11] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 5, 7, 8, 0, 1, 6, 4, 3, 10, 9, 11] train accuracy: 0.620277777778 test accuracy: 0.587
# episode 75 end
# episode 76 start
# episode columns: [10, 4, 5, 2, 3, 9, 8, 7, 0, 6, 1, 11] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 5, 7, 8, 0, 6, 4, 3, 1, 9, 11, 10] train accuracy: 0.619518518519 test accuracy: 0.590333333333
# episode 76 end
# episode 77 start
# episode columns: [4, 3, 2, 5, 10, 7, 0, 1, 6, 8, 11, 9] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[2, 6, 4, 0, 8, 9, 1, 5, 7, 10, 3] train accuracy: 0.677388888889 test accuracy: 0.617833333333
# episode 77 end
# episode 78 start
# episode columns: [0, 2, 6, 4, 3, 9, 10, 8, 11, 1, 5, 7] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 8, 0, 1, 5, 7, 6, 4, 3, 10] train accuracy: 0.677166666667 test accuracy: 0.618166666667
# episode 78 end
# episode 79 start
# episode columns: [5, 0, 11, 10, 6, 7, 1, 4, 3, 9, 8, 2] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 8, 0, 1, 5, 7, 6, 4] train accuracy: 0.687185185185 test accuracy: 0.6465
# episode 79 end
# episode 80 start
# episode columns: [4, 1, 8, 10, 7, 5, 6, 11, 2, 3, 0, 9] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 9, 8, 0, 1, 5, 7, 6, 4] train accuracy: 0.687185185185 test accuracy: 0.647666666667
# episode 80 end
# episode 81 start
# episode columns: [2, 1, 0, 6, 3, 9, 11, 7, 4, 10, 8, 5] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 8, 0, 1, 5, 7, 6, 4, 10, 3] train accuracy: 0.677425925926 test accuracy: 0.6165
# episode 81 end
# episode 82 start
# episode columns: [9, 1, 2, 11, 10, 6, 8, 7, 5, 0, 3, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 8, 0, 1, 5, 7, 6, 4, 10, 3] train accuracy: 0.677166666667 test accuracy: 0.6175
# episode 82 end
# episode 83 start
# episode columns: [5, 7, 8, 11, 9, 0, 4, 6, 10, 1, 2, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677148148148 test accuracy: 0.616666666667
# episode 83 end
# episode 84 start
# episode columns: [3, 5, 2, 0, 6, 4, 11, 9, 1, 8, 7, 10] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677203703704 test accuracy: 0.617166666667
# episode 84 end
# episode 85 start
# episode columns: [1, 2, 6, 3, 9, 4, 0, 5, 7, 8, 11, 10] epsilon: 0.9 learning rate: 0.09 error: 0.15
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677240740741 test accuracy: 0.617166666667
# episode 85 end
# episode 86 start
# episode columns: [2, 1, 5, 7, 8, 0, 4, 9, 6, 11, 3, 10] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677259259259 test accuracy: 0.616666666667
# episode 86 end
# episode 87 start
# episode columns: [2, 1, 7, 10, 9, 5, 3, 8, 4, 11, 6, 0] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677222222222 test accuracy: 0.617166666667
# episode 87 end
# episode 88 start
# episode columns: [4, 0, 2, 8, 7, 5, 1, 3, 9, 6, 11, 10] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 0, 4, 8, 1, 5, 7, 6, 10, 3] train accuracy: 0.677314814815 test accuracy: 0.617666666667
# episode 88 end
# episode 89 start
# episode columns: [3, 10, 2, 7, 8, 9, 0, 1, 6, 4, 5, 11] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 9, 0, 4, 8, 1, 5, 11, 10, 7, 6, 3] train accuracy: 0.619407407407 test accuracy: 0.5855
# episode 89 end
# episode 90 start
# episode columns: [2, 0, 4, 3, 9, 11, 6, 5, 8, 1, 10, 7] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 0, 4, 8, 9, 7, 6, 10, 3, 1, 5, 11] train accuracy: 0.62037037037 test accuracy: 0.5815
# episode 90 end
# episode 91 start
# episode columns: [6, 10, 2, 9, 1, 0, 7, 11, 8, 4, 3, 5] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 0, 4, 8, 9, 7, 6, 10, 3, 1, 5, 11] train accuracy: 0.620037037037 test accuracy: 0.586833333333
# episode 91 end
# episode 92 start
# episode columns: [8, 2, 11, 6, 5, 3, 4, 0, 1, 7, 9, 10] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 0, 4, 8, 9, 7, 6, 10, 3, 1, 5, 11] train accuracy: 0.61962962963 test accuracy: 0.585333333333
# episode 92 end
# episode 93 start
# episode columns: [7, 9, 3, 8, 1, 2, 5, 11, 0, 10, 6, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 0, 4, 8, 1, 7, 6, 10, 3, 9] train accuracy: 0.682907407407 test accuracy: 0.624
# episode 93 end
# episode 94 start
# episode columns: [6, 0, 2, 5, 7, 1, 11, 10, 8, 4, 9, 3] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 0, 4, 8, 1, 7, 6, 10, 3, 9] train accuracy: 0.683166666667 test accuracy: 0.623666666667
# episode 94 end
# episode 95 start
# episode columns: [5, 8, 9, 4, 11, 0, 3, 2, 6, 7, 10, 1] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[2, 0, 4, 8, 1, 7, 6, 10, 3, 9] train accuracy: 0.683092592593 test accuracy: 0.6235
# episode 95 end
# episode 96 start
# episode columns: [9, 7, 3, 4, 1, 5, 11, 10, 8, 6, 0, 2] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 0, 4, 8, 1, 7, 6, 10, 3, 9] train accuracy: 0.683037037037 test accuracy: 0.624833333333
# episode 96 end
# episode 97 start
# episode columns: [4, 7, 6, 9, 3, 1, 5, 2, 0, 10, 8, 11] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.68312962963 test accuracy: 0.624
# episode 97 end
# episode 98 start
# episode columns: [0, 11, 7, 9, 10, 4, 2, 5, 3, 6, 8, 1] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.68312962963 test accuracy: 0.624
# episode 98 end
# episode 99 start
# episode columns: [7, 6, 3, 1, 0, 2, 8, 4, 9, 11, 10, 5] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683111111111 test accuracy: 0.624666666667
# episode 99 end
# episode 100 start
# episode columns: [1, 5, 4, 7, 6, 2, 10, 9, 8, 0, 3, 11] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683037037037 test accuracy: 0.624333333333
# episode 100 end
# episode 101 start
# episode columns: [2, 9, 6, 8, 3, 10, 5, 4, 11, 0, 1, 7] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683037037037 test accuracy: 0.623666666667
# episode 101 end
# episode 102 start
# episode columns: [10, 3, 7, 1, 8, 0, 11, 4, 2, 9, 6, 5] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683148148148 test accuracy: 0.623833333333
# episode 102 end
# episode 103 start
# episode columns: [5, 11, 9, 8, 6, 4, 3, 0, 10, 2, 1, 7] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683092592593 test accuracy: 0.6235
# episode 103 end
# episode 104 start
# episode columns: [4, 7, 2, 1, 9, 0, 8, 3, 6, 11, 5, 10] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 0, 4, 8, 1, 7, 6, 10, 3] train accuracy: 0.683203703704 test accuracy: 0.624
# episode 104 end
# episode 105 start
# episode columns: [1, 8, 3, 6, 4, 9, 7, 2, 11, 5, 0, 10] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 9, 0, 10, 7, 6, 4, 8, 1, 5] train accuracy: 0.681259259259 test accuracy: 0.621166666667
# episode 105 end
# episode 106 start
# episode columns: [0, 8, 11, 9, 6, 5, 1, 4, 7, 3, 10, 2] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 9, 0, 10, 7, 6, 4, 8, 1, 5] train accuracy: 0.681333333333 test accuracy: 0.621333333333
# episode 106 end
# episode 107 start
# episode columns: [6, 4, 10, 9, 0, 3, 5, 8, 7, 1, 2, 11] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 11, 10, 7, 6, 4, 0, 3, 1, 5] train accuracy: 0.623666666667 test accuracy: 0.5875
# episode 107 end
# episode 108 start
# episode columns: [5, 7, 9, 3, 1, 4, 8, 11, 10, 6, 2] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 11, 10, 7, 6, 4, 0, 3, 9, 8, 1, 5] train accuracy: 0.619740740741 test accuracy: 0.585
# episode 108 end
# episode 109 start
# episode columns: [9, 6, 5, 3, 8, 0, 1, 11, 4, 7, 2, 10] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 11, 10, 7, 6, 4, 0, 3, 9, 8, 1, 5] train accuracy: 0.619814814815 test accuracy: 0.5835
# episode 109 end
# episode 110 start
# episode columns: [9, 0, 2, 8, 3, 1, 6, 7, 10, 11, 5, 4] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 11, 10, 7, 6, 4, 0, 3, 9, 8, 1, 5] train accuracy: 0.619259259259 test accuracy: 0.586833333333
# episode 110 end
# episode 111 start
# episode columns: [8, 5, 11, 1, 0, 7, 2, 6, 4, 10, 9, 3] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 10, 9, 8, 0, 3, 7, 5, 1, 4] train accuracy: 0.677351851852 test accuracy: 0.616666666667
# episode 111 end
# episode 112 start
# episode columns: [0, 2, 10, 9, 1, 4, 8, 5, 6, 7, 11, 3] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 10, 9, 8, 0, 3, 7, 5, 1, 4] train accuracy: 0.67737037037 test accuracy: 0.616166666667
# episode 112 end
# episode 113 start
# episode columns: [0, 7, 8, 6, 4, 5, 3, 9, 10] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 10, 9, 8, 0, 3, 7, 5, 1, 4] train accuracy: 0.677259259259 test accuracy: 0.616666666667
# episode 113 end
# episode 114 start
# episode columns: [2, 8, 9, 10, 7, 0, 1, 11, 3, 5, 6, 4] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 6, 4, 0, 3, 9, 8, 1, 7, 5, 10] train accuracy: 0.67712962963 test accuracy: 0.616166666667
# episode 114 end
# episode 115 start
# episode columns: [1, 10, 7, 2, 6, 5, 0, 3, 4, 8, 11, 9] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 6, 4, 0, 3, 9, 8, 1, 7, 5, 10] train accuracy: 0.677111111111 test accuracy: 0.616666666667
# episode 115 end
# episode 116 start
# episode columns: [5, 10, 9, 0, 11, 4, 1, 7, 3, 6, 8, 2] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 4, 0, 3, 9, 8, 1, 7, 5, 10] train accuracy: 0.67737037037 test accuracy: 0.617666666667
# episode 116 end
# episode 117 start
# episode columns: [4, 1, 3, 11, 10, 5, 2, 8, 7, 0, 9, 6] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 6, 4, 0, 3, 9, 8, 7, 5, 1] train accuracy: 0.684240740741 test accuracy: 0.637833333333
# episode 117 end
# episode 118 start
# episode columns: [2, 5, 8, 3, 7, 11, 10, 1, 0, 9, 4] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677407407407 test accuracy: 0.617
# episode 118 end
# episode 119 start
# episode columns: [11, 5, 6, 1, 3, 7, 0, 4, 9, 10, 2, 8] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677166666667 test accuracy: 0.617166666667
# episode 119 end
# episode 120 start
# episode columns: [9, 7, 2, 8, 11, 10, 0, 1, 5, 4, 3, 6] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677185185185 test accuracy: 0.617166666667
# episode 120 end
# episode 121 start
# episode columns: [3, 1, 8, 4, 0, 6, 2, 11, 7, 5, 9, 10] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677240740741 test accuracy: 0.616666666667
# episode 121 end
# episode 122 start
# episode columns: [6, 9, 3, 5, 0, 2, 8, 11, 1, 7, 4, 10] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677407407407 test accuracy: 0.617333333333
# episode 122 end
# episode 123 start
# episode columns: [6, 4, 3, 8, 9, 5, 10, 1, 2, 11, 0, 7] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677185185185 test accuracy: 0.617
# episode 123 end
# episode 124 start
# episode columns: [1, 5, 10, 11, 0, 8, 9, 6, 7, 2, 4, 3] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.67712962963 test accuracy: 0.616166666667
# episode 124 end
# episode 125 start
# episode columns: [8, 4, 6, 3, 9, 1, 5, 7, 10, 2, 11, 0] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.677314814815 test accuracy: 0.6175
# episode 125 end
# episode 126 start
# episode columns: [2, 3, 8, 1, 9, 7, 4, 10, 6, 5, 11, 0] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.677203703704 test accuracy: 0.616666666667
# episode 126 end
# episode 127 start
# episode columns: [7, 9, 1, 0, 8, 4, 3, 2, 6, 10, 5, 11] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.677259259259 test accuracy: 0.616666666667
# episode 127 end
# episode 128 start
# episode columns: [8, 0, 6, 9, 5, 11, 7, 4, 10, 1, 2, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.677314814815 test accuracy: 0.616333333333
# episode 128 end
# episode 129 start
# episode columns: [2, 1, 10, 7, 9, 0, 11, 4, 8, 5, 3, 6] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 6, 4, 0, 3, 7, 5, 10, 9, 8, 1] train accuracy: 0.677351851852 test accuracy: 0.617166666667
# episode 129 end
# episode 130 start
# episode columns: [2, 0, 11, 6, 9, 5, 1, 4, 8, 10, 7, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621740740741 test accuracy: 0.585
# episode 130 end
# episode 131 start
# episode columns: [6, 11, 10, 9, 4, 1, 2, 5, 8, 0, 7, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621444444444 test accuracy: 0.586166666667
# episode 131 end
# episode 132 start
# episode columns: [6, 4, 10, 0, 3, 7, 11, 9, 5, 1, 2, 8] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621259259259 test accuracy: 0.584666666667
# episode 132 end
# episode 133 start
# episode columns: [4, 9, 3, 6, 5, 8, 0, 1, 2, 7, 11, 10] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621314814815 test accuracy: 0.583833333333
# episode 133 end
# episode 134 start
# episode columns: [6, 10, 0, 2, 8, 11, 4, 1, 9, 3, 7, 5] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621314814815 test accuracy: 0.583166666667
# episode 134 end
# episode 135 start
# episode columns: [11, 9, 6, 10, 4, 2, 3, 0, 5, 8, 7, 1] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.622018518519 test accuracy: 0.584
# episode 135 end
# episode 136 start
# episode columns: [3, 6, 8, 7, 4, 9, 2, 11, 1, 5, 0, 10] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621425925926 test accuracy: 0.585
# episode 136 end
# episode 137 start
# episode columns: [6, 4, 3, 8, 7, 10, 11, 0, 2, 1, 9, 5] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 6, 4, 0, 11, 10, 7, 5, 1, 8, 9] train accuracy: 0.621685185185 test accuracy: 0.583833333333
# episode 137 end
# episode 138 start
# episode columns: [2, 6, 0, 11, 9, 10, 3, 4, 5, 1, 8, 7] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[6, 4, 0, 2, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677185185185 test accuracy: 0.617666666667
# episode 138 end
# episode 139 start
# episode columns: [3, 2, 4, 5, 11, 10, 7, 0, 9, 8, 6, 1] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[6, 4, 0, 2, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677222222222 test accuracy: 0.617
# episode 139 end
# episode 140 start
# episode columns: [5, 9, 8, 7, 1, 3, 11, 10, 2, 6, 0, 4] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[6, 4, 0, 2, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677314814815 test accuracy: 0.616666666667
# episode 140 end
# episode 141 start
# episode columns: [6, 4, 10, 0, 11, 5, 7, 2, 8, 1, 9, 3] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677388888889 test accuracy: 0.616
# episode 141 end
# episode 142 start
# episode columns: [2, 4, 8, 1, 10, 11, 3, 9, 7, 6, 0, 5] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 6, 4, 0, 3, 7, 5, 1, 8, 9, 10] train accuracy: 0.677166666667 test accuracy: 0.617333333333
# episode 142 end
# episode 143 start
# episode columns: [2, 11, 10, 3, 0, 9, 1, 4, 8, 7, 5, 6] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677148148148 test accuracy: 0.6165
# episode 143 end
# episode 144 start
# episode columns: [0, 6, 9, 1, 10, 5, 11, 3, 2, 4, 7, 8] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677222222222 test accuracy: 0.616833333333
# episode 144 end
# episode 145 start
# episode columns: [0, 6, 4, 11, 1, 7, 2, 8, 10, 5, 3, 9] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677333333333 test accuracy: 0.617833333333
# episode 145 end
# episode 146 start
# episode columns: [2, 6, 1, 8, 0, 10, 5, 11, 9, 4, 3, 7] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677333333333 test accuracy: 0.617333333333
# episode 146 end
# episode 147 start
# episode columns: [2, 5, 10, 9, 1, 7, 6, 4, 0, 11, 3, 8] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677222222222 test accuracy: 0.616666666667
# episode 147 end
# episode 148 start
# episode columns: [9, 0, 10, 1, 2, 3, 8, 7, 5, 6, 11, 4] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 6, 4, 0, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.677185185185 test accuracy: 0.617
# episode 148 end
# episode 149 start
# episode columns: [3, 8, 7, 0, 11, 2, 6, 4, 1, 10, 5, 9] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 6, 4, 0, 11, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.61987037037 test accuracy: 0.585833333333
# episode 149 end
# episode 150 start
# episode columns: [9, 1, 11, 6, 10, 4, 7, 5, 0, 3, 2, 8] epsilon: 0.9 learning rate: 0.09 error: 0.15
# episode policy:[2, 6, 4, 0, 11, 3, 7, 9, 8, 1, 5, 10] train accuracy: 0.619611111111 test accuracy: 0.584166666667
# episode 150 end
# episode 151 start
# episode columns: [6, 3, 4, 10, 0, 11, 2, 9, 7, 5, 1, 8] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 6, 4, 0, 11, 3, 7, 5, 1] train accuracy: 0.635907407407 test accuracy: 0.588333333333
# episode 151 end
# episode 152 start
# episode columns: [6, 2, 0, 4, 3, 10, 1, 11, 5, 7, 8, 9] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 6, 4, 0, 11, 3, 7, 5, 1] train accuracy: 0.635962962963 test accuracy: 0.585666666667
# episode 152 end
# episode 153 start
# episode columns: [4, 8, 7, 10, 5, 1, 11, 0, 2, 6, 3, 9] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 1, 7, 5, 10] train accuracy: 0.619537037037 test accuracy: 0.585833333333
# episode 153 end
# episode 154 start
# episode columns: [10, 7, 9, 11, 0, 3, 6, 8, 4, 2, 1, 5] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 1, 7, 5, 10] train accuracy: 0.619759259259 test accuracy: 0.585166666667
# episode 154 end
# episode 155 start
# episode columns: [10, 5, 3, 8, 1, 9, 11, 4, 2, 0, 7, 6] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 7, 5, 1] train accuracy: 0.631685185185 test accuracy: 0.5855
# episode 155 end
# episode 156 start
# episode columns: [0, 2, 8, 3, 5, 6, 4, 1, 10, 11, 7, 9] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 7, 5, 1, 10] train accuracy: 0.620444444444 test accuracy: 0.585333333333
# episode 156 end
# episode 157 start
# episode columns: [8, 3, 0, 5, 9, 6, 1, 4, 11, 7, 2, 10] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 7, 5, 1, 10] train accuracy: 0.619333333333 test accuracy: 0.585166666667
# episode 157 end
# episode 158 start
# episode columns: [8, 0, 7, 10, 4, 5, 2, 1, 11, 3, 9, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 3, 6, 4, 0, 11, 9, 8, 7, 5, 1, 10] train accuracy: 0.619351851852 test accuracy: 0.5865
# episode 158 end
# episode 159 start
# episode columns: [9, 4, 0, 5, 7, 3, 11, 1, 10, 2, 6, 8] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 3, 6, 4, 7, 5, 0, 11, 9, 8, 1, 10] train accuracy: 0.619537037037 test accuracy: 0.585
# episode 159 end
# episode 160 start
# episode columns: [7, 9, 2, 5, 10, 3, 6, 4, 0, 8, 11, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 3, 6, 4, 7, 5, 0, 11, 9, 8, 1, 10] train accuracy: 0.619574074074 test accuracy: 0.585333333333
# episode 160 end
# episode 161 start
# episode columns: [8, 7, 2, 9, 10, 1, 3, 6, 0, 11, 5, 4] epsilon: 0.9 learning rate: 0.09 error: 0.7
# episode policy:[2, 9, 8, 0, 3, 6, 4, 7, 5, 1, 10] train accuracy: 0.677203703704 test accuracy: 0.6165
# episode 161 end
# episode 162 start
# episode columns: [9, 1, 2, 0, 3, 11, 6, 10, 7, 8, 4, 5] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 9, 8, 0, 3, 6, 4, 7, 5, 1, 10] train accuracy: 0.677240740741 test accuracy: 0.617
# episode 162 end
# episode 163 start
# episode columns: [11, 4, 5, 6, 8, 9, 10, 3, 1, 7, 0, 2] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 9, 10, 5, 6, 0, 3, 7, 4, 11, 8, 1] train accuracy: 0.619388888889 test accuracy: 0.584
# episode 163 end
# episode 164 start
# episode columns: [8, 1, 3, 11, 9, 6, 2, 4, 10, 7, 5, 0] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[2, 9, 10, 5, 0, 3, 6, 4, 7] train accuracy: 0.686407407407 test accuracy: 0.655833333333
# episode 164 end
# episode 165 start
# episode columns: [6, 3, 0, 5, 9, 7, 11, 2, 8, 1, 4, 10] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[2, 9, 10, 5, 0, 3, 6, 4, 7] train accuracy: 0.686240740741 test accuracy: 0.6555
# episode 165 end
# episode 166 start
# episode columns: [10, 5, 2, 0, 11, 7, 1, 6, 3, 8, 9, 4] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 10, 7, 4, 0, 3, 6, 1, 5] train accuracy: 0.681648148148 test accuracy: 0.6295
# episode 166 end
# episode 167 start
# episode columns: [2, 9, 8, 6, 0, 1, 11, 4, 10, 5, 7, 3] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 10, 7, 4, 0, 3, 6, 1, 5] train accuracy: 0.681592592593 test accuracy: 0.631333333333
# episode 167 end
# episode 168 start
# episode columns: [8, 1, 9, 2, 10, 5, 7, 11, 3, 4, 0, 6] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 10, 7, 4, 0, 3, 6, 1, 5] train accuracy: 0.68162962963 test accuracy: 0.630333333333
# episode 168 end
# episode 169 start
# episode columns: [3, 6, 7, 9, 11, 0, 8, 5, 1, 10, 4, 2] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[2, 9, 10, 7, 4, 0, 3, 6, 1, 5] train accuracy: 0.681703703704 test accuracy: 0.631
# episode 169 end
# episode 170 start
# episode columns: [3, 11, 10, 6, 7, 5, 9, 4, 1, 8, 0, 2] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[2, 9, 10, 7, 5, 0, 3, 6, 4, 11, 8, 1] train accuracy: 0.619944444444 test accuracy: 0.585666666667
# episode 170 end
# episode 171 start
# episode columns: [10, 0, 4, 7, 9, 2, 6, 3, 8, 11, 1, 5] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 10, 7, 5, 0, 3, 6, 4, 11, 8, 1] train accuracy: 0.618907407407 test accuracy: 0.586166666667
# episode 171 end
# episode 172 start
# episode columns: [8, 5, 0, 2, 6, 9, 11, 4, 7, 1, 10, 3] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[2, 9, 10, 7, 5, 6, 0, 3, 4, 11, 8, 1] train accuracy: 0.61962962963 test accuracy: 0.586833333333
# episode 172 end
# episode 173 start
# episode columns: [11, 8, 2, 9, 7, 6, 0, 1, 5, 4, 10, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[2, 9, 10, 7, 5, 6, 0, 3, 4, 11, 8, 1] train accuracy: 0.619462962963 test accuracy: 0.587333333333
# episode 173 end
# episode 174 start
# episode columns: [6, 1, 9, 7, 11, 0, 10, 5, 8, 3, 2, 4] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[2, 9, 10, 5, 6, 0, 3, 7, 4, 11, 8, 1] train accuracy: 0.619814814815 test accuracy: 0.590166666667
# episode 174 end
# episode 175 start
# episode columns: [4, 5, 2, 3, 8, 11, 10, 1, 7, 6, 9, 0] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[4, 7, 2, 9, 10, 5, 6, 0, 3] train accuracy: 0.686407407407 test accuracy: 0.656166666667
# episode 175 end
# episode 176 start
# episode columns: [2, 9, 6, 8, 1, 10, 5, 0, 11, 3, 7, 4] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[4, 7, 2, 9, 10, 5, 0, 3, 6, 1] train accuracy: 0.681592592593 test accuracy: 0.630833333333
# episode 176 end
# episode 177 start
# episode columns: [4, 8, 7, 1, 11, 6, 2, 9, 0, 10, 5, 3] epsilon: 0.9 learning rate: 0.09 error: 0.7
# episode policy:[3, 7, 2, 9, 10, 5, 0, 8, 4, 11, 6, 1] train accuracy: 0.619833333333 test accuracy: 0.584833333333
# episode 177 end
# episode 178 start
# episode columns: [10, 0, 3, 9, 7, 2, 8, 11, 1, 4, 6, 5] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[10, 5, 0, 2, 9, 8, 4, 7] train accuracy: 0.687814814815 test accuracy: 0.649
# episode 178 end
# episode 179 start
# episode columns: [3, 10, 5, 0, 7, 11, 4, 1, 6, 9, 8, 2] epsilon: 0.9 learning rate: 0.09 error: 0.6
# episode policy:[10, 5, 6, 0, 2, 9, 8, 4, 7] train accuracy: 0.685740740741 test accuracy: 0.650333333333
# episode 179 end
# episode 180 start
# episode columns: [8, 10, 0, 3, 11, 7, 5, 2, 1, 6, 4, 9] epsilon: 0.9 learning rate: 0.09 error: 0.25
# episode policy:[10, 5, 6, 0, 2, 9, 8, 4, 7] train accuracy: 0.685722222222 test accuracy: 0.65
# episode 180 end
# episode 181 start
# episode columns: [7, 3, 8, 1, 10, 2, 0, 9, 4, 5, 11, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 9, 8, 4, 7] train accuracy: 0.685648148148 test accuracy: 0.651666666667
# episode 181 end
# episode 182 start
# episode columns: [3, 10, 1, 7, 0, 11, 9, 8, 5, 2, 4, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 9, 7, 4, 11, 3, 8, 1] train accuracy: 0.619351851852 test accuracy: 0.583666666667
# episode 182 end
# episode 183 start
# episode columns: [5, 0, 1, 6, 8, 4, 7, 10, 9, 3, 2, 11] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[10, 5, 6, 0, 2, 9, 7, 4, 11, 3, 8, 1] train accuracy: 0.620203703704 test accuracy: 0.585
# episode 183 end
# episode 184 start
# episode columns: [10, 0, 5, 6, 1, 9, 3, 8, 11, 7, 2, 4] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[10, 5, 6, 0, 2, 9, 7, 4, 11, 3, 8, 1] train accuracy: 0.619814814815 test accuracy: 0.587666666667
# episode 184 end
# episode 185 start
# episode columns: [11, 7, 6, 0, 2, 9, 3, 8, 5, 4, 10, 1] epsilon: 0.9 learning rate: 0.09 error: 0.3
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.688981481481 test accuracy: 0.659666666667
# episode 185 end
# episode 186 start
# episode columns: [5, 8, 7, 1, 9, 11, 4, 10, 0, 2, 3, 6] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.689 test accuracy: 0.660166666667
# episode 186 end
# episode 187 start
# episode columns: [10, 8, 3, 1, 2, 7, 9, 4, 5, 11, 0, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.689074074074 test accuracy: 0.659833333333
# episode 187 end
# episode 188 start
# episode columns: [3, 1, 7, 2, 0, 5, 8, 4, 11, 9, 10, 6] epsilon: 0.9 learning rate: 0.09 error: 0.55
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.688962962963 test accuracy: 0.659833333333
# episode 188 end
# episode 189 start
# episode columns: [6, 0, 11, 3, 7, 2, 5, 9, 10, 8, 1, 4] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.688962962963 test accuracy: 0.66
# episode 189 end
# episode 190 start
# episode columns: [10, 1, 0, 8, 6, 9, 7, 2, 3, 4, 11, 5] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 4, 9, 7] train accuracy: 0.689037037037 test accuracy: 0.659833333333
# episode 190 end
# episode 191 start
# episode columns: [4, 10, 0, 8, 1, 9, 3, 2, 7, 5, 6] epsilon: 0.9 learning rate: 0.09 error: 0.4
# episode policy:[10, 5, 6, 0, 2, 4, 9, 3, 8, 1, 7] train accuracy: 0.677185185185 test accuracy: 0.616833333333
# episode 191 end
# episode 192 start
# episode columns: [1, 4, 9, 11, 10, 6, 0, 5, 2, 8, 7, 3] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[10, 5, 6, 0, 2, 4, 9, 3, 8, 1, 7] train accuracy: 0.677277777778 test accuracy: 0.617666666667
# episode 192 end
# episode 193 start
# episode columns: [9, 1, 5, 7, 4, 2, 3, 6, 0, 11, 8, 10] epsilon: 0.9 learning rate: 0.09 error: 0.2
# episode policy:[10, 5, 6, 0, 2, 4, 9, 3, 8, 1, 7] train accuracy: 0.677240740741 test accuracy: 0.616666666667
# episode 193 end
# episode 194 start
# episode columns: [4, 9, 10, 1, 2, 3, 5, 0, 6, 7, 11, 8] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[10, 5, 0, 2, 4, 7, 9, 3, 8, 1, 6] train accuracy: 0.677296296296 test accuracy: 0.616333333333
# episode 194 end
# episode 195 start
# episode columns: [5, 9, 8, 1, 11, 3, 7, 10, 6, 0, 4, 2] epsilon: 0.9 learning rate: 0.09 error: 0.35
# episode policy:[10, 5, 0, 2, 4, 7, 9, 3, 8, 1, 6] train accuracy: 0.677222222222 test accuracy: 0.617833333333
# episode 195 end
# episode 196 start
# episode columns: [6, 3, 9, 11, 0, 10, 5, 1, 4, 7, 2, 8] epsilon: 0.9 learning rate: 0.09 error: 0.45
# episode policy:[10, 5, 0, 2, 4, 7, 9, 3, 8, 1, 6] train accuracy: 0.677259259259 test accuracy: 0.617166666667
# episode 196 end
# episode 197 start
# episode columns: [3, 7, 8, 1, 4, 11, 5, 0, 2, 10, 9, 6] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[10, 5, 0, 2, 4, 7, 9, 3, 8, 6, 1] train accuracy: 0.677314814815 test accuracy: 0.617166666667
# episode 197 end
# episode 198 start
# episode columns: [5, 11, 4, 10, 0, 6, 1, 3, 8, 2, 9, 7] epsilon: 0.9 learning rate: 0.09 error: 0.5
# episode policy:[10, 5, 0, 2, 4, 7, 9, 3, 8, 6, 1] train accuracy: 0.677185185185 test accuracy: 0.617166666667
# episode 198 end
# episode 199 start
# episode columns: [6, 0, 8, 2, 7, 5, 10, 9, 1, 3, 4, 11] epsilon: 0.9 learning rate: 0.09 error: 0.35
# ...
# episode columns: [6, 4, 1, 0, 10, 9, 11, 8, 5] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7643 end
# episode 7644 start
# episode columns: [9, 7, 8, 10, 11, 2, 6, 5, 4, 0, 3, 1] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7644 end
# episode 7645 start
# episode columns: [8, 9, 7, 2, 5, 3, 10, 11, 6, 4, 0, 1] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7645 end
# episode 7646 start
# episode columns: [8, 9, 0, 3, 10, 1, 4, 7, 5, 6] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7646 end
# episode 7647 start
# episode columns: [7, 5, 4, 6, 3, 2, 1, 9] epsilon: 0.5 learning rate: 0.05 error: 0.25
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7647 end
# episode 7648 start
# episode columns: [6, 8, 9, 2, 1, 0, 7, 4, 5, 11, 10, 3] epsilon: 0.5 learning rate: 0.05 error: 0.25
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7648 end
# episode 7649 start
# episode columns: [8, 10, 4, 7, 5, 3, 1, 6, 11, 2, 0, 9] epsilon: 0.5 learning rate: 0.05 error: 0.3
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7649 end
# episode 7650 start
# episode columns: [8, 9, 7, 5, 0, 11, 6, 4, 10, 2, 1, 3] epsilon: 0.5 learning rate: 0.05 error: 0.25
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7650 end
# episode 7651 start
# episode columns: [10, 4, 5, 6, 3, 9, 7, 1, 8] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7651 end
# episode 7652 start
# episode columns: [8, 4, 3, 7, 0, 10, 6, 2, 11, 5, 9] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7652 end
# episode 7653 start
# episode columns: [1, 5, 4, 7, 6, 3, 9] epsilon: 0.5 learning rate: 0.05 error: 0.15
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7653 end
# episode 7654 start
# episode columns: [4, 7, 5, 6, 3, 10, 1, 9] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 5, 4, 3, 10, 6] train accuracy: 0.696537037037 test accuracy: 0.688666666667
# episode 7654 end
# episode 7655 start
# episode columns: [9, 6, 3, 10, 1, 11, 7, 5, 2, 0, 8, 4] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7655 end
# episode 7656 start
# episode columns: [8, 7, 1, 9, 6, 4, 3, 2] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7656 end
# episode 7657 start
# episode columns: [8, 4, 11, 6, 1, 10, 9, 5, 0, 7, 3] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7657 end
# episode 7658 start
# episode columns: [3, 2, 11, 0, 9, 7, 6, 1, 5, 4] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7658 end
# episode 7659 start
# episode columns: [7, 6, 4, 3, 10, 9, 1, 2, 5, 0, 8, 11] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7659 end
# episode 7660 start
# episode columns: [11, 6, 4, 1, 8, 5] epsilon: 0.5 learning rate: 0.05 error: 0.25
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7660 end
# episode 7661 start
# episode columns: [6, 4, 5, 8, 0, 7, 2, 9] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7661 end
# episode 7662 start
# episode columns: [8, 5, 4, 1, 9, 7, 6, 3, 0, 2] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7662 end
# episode 7663 start
# episode columns: [8, 6, 0, 11, 5, 4, 7, 1, 3, 10, 9] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7663 end
# episode 7664 start
# episode columns: [11, 6, 4, 7, 10, 9, 8, 1] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7664 end
# episode 7665 start
# episode columns: [9, 10, 4, 1, 6, 3, 2, 8, 0, 7, 5, 11] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7665 end
# episode 7666 start
# episode columns: [8, 9, 7, 6, 4, 3, 2] epsilon: 0.5 learning rate: 0.05 error: 0.15
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7666 end
# episode 7667 start
# episode columns: [5, 9, 11, 7, 0, 4, 3, 10, 2, 1, 6, 8] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7667 end
# episode 7668 start
# episode columns: [4, 7, 2, 9, 8, 10, 6, 3, 1] epsilon: 0.5 learning rate: 0.05 error: 0.6
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7668 end
# episode 7669 start
# episode columns: [8, 9, 7, 5, 11, 6, 4, 2, 0, 1, 3, 10] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7669 end
# episode 7670 start
# episode columns: [8, 9, 5, 0, 4, 6, 10, 11, 7, 3, 1, 2] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7670 end
# episode 7671 start
# episode columns: [8, 10, 2, 6, 4, 7, 3, 9, 5, 1] epsilon: 0.5 learning rate: 0.05 error: 0.6
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7671 end
# episode 7672 start
# episode columns: [8, 4, 6, 5] epsilon: 0.5 learning rate: 0.05 error: 0.2
# episode policy:[8, 9, 7, 6, 4, 3, 10] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7672 end
# episode 7673 start
# episode columns: [8, 9, 1, 5, 4, 7, 3, 6, 0, 2, 11, 10] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7673 end
# episode 7674 start
# episode columns: [8, 4, 7, 5, 10, 9, 6, 1, 2, 11, 3, 0] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7674 end
# episode 7675 start
# episode columns: [6, 9, 1, 8, 7, 2, 4, 3, 0, 10] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7675 end
# episode 7676 start
# episode columns: [8, 2, 0, 5, 4, 7, 3, 10, 11, 1, 9, 6] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7676 end
# episode 7677 start
# episode columns: [8, 5, 4, 10, 6, 3, 9, 7, 11, 2] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7677 end
# episode 7678 start
# episode columns: [8, 9, 5, 10, 4, 3, 6, 2, 1, 7] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7678 end
# episode 7679 start
# episode columns: [8, 9, 1, 4, 11, 10, 6, 3, 2] epsilon: 0.5 learning rate: 0.05 error: 0.3
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7679 end
# episode 7680 start
# episode columns: [8, 7, 3, 11, 0, 1, 9] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7680 end
# episode 7681 start
# episode columns: [8, 1, 9, 11, 10, 4, 7, 5, 6, 3, 2] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7681 end
# episode 7682 start
# episode columns: [11, 0, 4, 9, 8, 10, 6, 3, 7, 2, 1, 5] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7682 end
# episode 7683 start
# episode columns: [11, 6, 4, 9, 7, 3, 10] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7683 end
# episode 7684 start
# episode columns: [8, 9, 7, 3, 10, 2, 6, 4, 1, 11, 5, 0] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7684 end
# episode 7685 start
# episode columns: [8, 9, 4, 10, 6, 3, 2] epsilon: 0.5 learning rate: 0.05 error: 0.3
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7685 end
# episode 7686 start
# episode columns: [8, 9, 7, 0, 3, 11, 6, 4, 1, 10] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7686 end
# episode 7687 start
# episode columns: [8, 9, 7, 3, 10, 4, 6, 1, 2, 0, 11, 5] epsilon: 0.5 learning rate: 0.05 error: 0.25
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7687 end
# episode 7688 start
# episode columns: [8, 6, 9, 3, 10, 11, 5, 4, 0, 2, 7, 1] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7688 end
# episode 7689 start
# episode columns: [8, 9, 7, 3, 10, 4, 6, 1, 5, 11] epsilon: 0.5 learning rate: 0.05 error: 0.2
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7689 end
# episode 7690 start
# episode columns: [9, 7, 3, 10, 8, 6, 4, 1, 5, 0, 11] epsilon: 0.5 learning rate: 0.05 error: 0.3
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7690 end
# episode 7691 start
# episode columns: [8, 9, 2, 4, 1, 10, 7, 3, 6] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7691 end
# episode 7692 start
# episode columns: [11, 8, 9, 5, 4, 0, 7, 3, 1, 6, 10, 2] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7692 end
# episode 7693 start
# episode columns: [8, 7, 3, 0, 11, 9, 1, 2, 6, 10, 4] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7693 end
# episode 7694 start
# episode columns: [8, 9, 7, 6, 10, 4, 3, 2, 5, 11, 1, 0] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7694 end
# episode 7695 start
# episode columns: [8, 9, 11, 6, 5, 7, 3, 10, 4, 2] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7695 end
# episode 7696 start
# episode columns: [4, 1, 9, 8, 10, 6, 2, 5] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7696 end
# episode 7697 start
# episode columns: [9, 7, 8, 10, 4, 6, 5, 3, 1, 0, 11] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7697 end
# episode 7698 start
# episode columns: [9, 5, 3, 8, 2, 11, 6, 10, 0, 7, 1] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7698 end
# episode 7699 start
# episode columns: [8, 9, 7, 3, 0, 4, 1, 10, 5, 11, 6] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7699 end
# episode 7700 start
# episode columns: [8, 9, 7, 0, 4, 11, 10, 6, 3] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7700 end
# episode 7701 start
# episode columns: [2, 6, 7, 3, 0, 10, 11, 8, 9, 4, 1, 5] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7701 end
# episode 7702 start
# episode columns: [1, 10, 6, 4, 9, 0, 7, 8, 5] epsilon: 0.5 learning rate: 0.05 error: 0.6
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7702 end
# episode 7703 start
# episode columns: [6, 10, 0, 7, 3, 9, 2, 4] epsilon: 0.5 learning rate: 0.05 error: 0.65
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7703 end
# episode 7704 start
# episode columns: [8, 7, 3, 10, 4, 5, 0, 11, 1, 9, 6, 2] epsilon: 0.5 learning rate: 0.05 error: 0.55
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7704 end
# episode 7705 start
# episode columns: [8, 5, 4, 1, 9, 3, 10, 11, 0, 7, 2, 6] epsilon: 0.5 learning rate: 0.05 error: 0.4
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7705 end
# episode 7706 start
# episode columns: [1, 5, 8, 9, 7, 10, 3, 6, 4, 11, 0] epsilon: 0.5 learning rate: 0.05 error: 0.35
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7706 end
# episode 7707 start
# episode columns: [9, 7, 3, 10, 4, 6, 1, 8] epsilon: 0.5 learning rate: 0.05 error: 0.3
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7707 end
# episode 7708 start
# episode columns: [5, 3, 6, 11, 7, 10, 2, 0, 8, 9, 4] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 3, 10, 4, 6, 1, 5] train accuracy: 0.696185185185 test accuracy: 0.685833333333
# episode 7708 end
# episode 7709 start
# episode columns: [8, 11, 10, 4, 0, 7, 3, 2, 5, 6, 1, 9] epsilon: 0.5 learning rate: 0.05 error: 0.65
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7709 end
# episode 7710 start
# episode columns: [8, 3, 9, 10, 6, 7, 1, 5, 4, 2] epsilon: 0.5 learning rate: 0.05 error: 0.5
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7710 end
# episode 7711 start
# episode columns: [10, 7, 5, 11, 1, 8, 0, 4, 3, 9] epsilon: 0.5 learning rate: 0.05 error: 0.45
# episode policy:[8, 9, 7, 3, 10, 4, 6] train accuracy: 0.696518518519 test accuracy: 0.689166666667
# episode 7711 end
